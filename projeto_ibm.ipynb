# %% [markdown]
# ## O dataset
#
# O dataset a ser utilizado é o *IBM HR Analytics Employee Attrition & Performance*, disponível no Kaggle. O dataset contém informações sobre funcionários de uma empresa fictícia, como idade, gênero, estado civil, nível de satisfação, entre outros. O objetivo é prever a probabilidade de um funcionário sair da empresa.
#
# [Link do Kaggle](https://www.kaggle.com/datasets/pavansubhasht/ibm-hr-analytics-attrition-dataset/data)
#
# Os termos *attrition* ("atrito") e *turnover* ("rotatividade") são frequentemente usados de forma intercambiável no contexto de recursos humanos e gestão de força de trabalho, mas eles se referem a conceitos ligeiramente diferentes em relação às mudanças no número e na composição dos empregados dentro de uma organização. Compreender a distinção entre esses dois é importante para analisar e relatar com precisão a dinâmica da força de trabalho.
#
# ### Atrito
#
# Atrito refere-se à redução gradual de empregados por meio de circunstâncias naturais, como aposentadoria, demissão voluntária por motivos pessoais, ou a decisão de não substituir empregados que estão de saída. Atrito pode levar a uma diminuição no tamanho da força de trabalho, mas é caracterizado por sua natureza voluntária e muitas vezes incontrolável. Organizações podem permitir o atrito para reduzir o tamanho de sua força de trabalho sem recorrer a demissões, vendo isso como uma forma menos disruptiva de ajustar seus níveis de pessoal.
#
# Em análises, quando você está analisando um conjunto de dados para atrito, você frequentemente olha para as razões por trás das saídas voluntárias e a taxa na qual estas ocorrem naturalmente ao longo do tempo. Taxas de atrito podem fornecer insights sobre a satisfação dos empregados e tendências de longo prazo da força de trabalho.
#
# ### Rotatividade
#
# Rotatividade, por outro lado, engloba um escopo mais amplo de partidas de empregados, incluindo tanto renúncias voluntárias quanto demissões involuntárias (como demissões ou términos por justa causa). Porém, ocorre a substituição da força de trabalho. Rotatividade é uma medida de quantos empregados estão deixando a companhia por qualquer motivo. Uma alta taxa de rotatividade pode indicar problemas com satisfação no trabalho, cultura do local de trabalho, ou estabilidade organizacional, e frequentemente requer ação da gestão para endereçar as causas subjacentes.
#
# Rotatividade é calculada dividindo o número de empregados que saem pelo número médio de empregados, geralmente em uma base anual, e expressando isso como uma porcentagem. Esta métrica é crucial para entender como as saídas de empregados, tanto voluntárias quanto involuntárias, afetam a capacidade da organização de manter uma força de trabalho estável e eficaz.
#
# ### Diferenças Chave
#
# - **Natureza**: Atrito geralmente é voluntário e pode ser devido a fatores naturais ou incontroláveis, enquanto rotatividade inclui tanto saídas voluntárias quanto demissões involuntárias.
# - **Implicações para Gestão**: Atrito pode ser parte de uma estratégia de ajuste natural da força de trabalho e nem sempre é negativo, enquanto alta rotatividade é frequentemente um sinal de problemas dentro da organização que precisam ser abordados.
# - **Foco Estratégico**: Análise de atrito pode focar em entender tendências de longo prazo da força de trabalho e planejamento de aposentadoria, enquanto análise de rotatividade é frequentemente usada para identificar questões imediatas com satisfação de empregados, engajamento, ou práticas de gestão que podem estar impactando a retenção de staff.
#
# Enquanto ambos atrito e rotatividade lidam com empregados deixando a organização, eles diferem em seu escopo e as implicações estratégicas para gerenciar e entender a dinâmica da força de trabalho. No seu conjunto de dados de empregados, distinguir entre atrito e rotatividade pode ajudar na customização de estratégias para planejamento da força de trabalho, retenção e desenvolvimento organizacional.

# %% [markdown]
# |    | Name                       | Description                                                                                                                                                    |
# |---:|:---------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  0 | Age                        | Numerical Value                                                                                                                                                |
# |  1 | Attrition                  | Employee leaving the company - Text - No, Yes                                                                                                                     |
# |  2 | BusinessTravel            | Text - Non-Travel, Travel_Frequently, Travel_Rarely                                                                                                             |
# |  3 | DailyRate                 | Numerical Value - Salary Level                                                                                                                                 |
# |  4 | Department                 | Text - Sales, Research & Development, Human Resources                                                                                                         |
# |  5 | DistanceFromHome         | Numerical Value - the distance from work to home in miles
# |  6 | Education                  | Numerical Value - 1=Below college, 2=College, 3=Bachelor, 4=Master, 5=PhD   |
# |  7 | EducationField            | Text - Life Sciences, Medical, Marketing, Techincal Degree, Human Resources, Other                                                                                   |
# |  8 | EmployeeCount             | Numerical Value - 1                                                                                                                                               |
# |  9 | EmployeeNumber            | Numerical Value - Employee ID                                                                                                                                  |
# | 10 | EnvironmentSatisfaction    | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High |
# | 11 | Gender                     | Text - Female, Male                                                                                                                                             |
# | 12 | HourlyRate                | Numerical Value - Hourly Salary                                                                                                                                |
# | 13 | JobInvolvement            | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 14 | JobLevel                  | Numerical Value - 1, 2, 3, 4, 5. Means different job levels                                                                                                     |
# | 15 | JobRole                   | Text - Sales Executive, Research Scientist, Laboratory Technician, Manufacturing Director, Healthcare Representative, Manager, Sales Representative, Research Director, Human Resources |
# | 16 | JobSatisfaction           | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 17 | MaritalStatus             | Text - Single, Married, Divorced                                                                                                                                      |
# | 18 | MonthlyIncome             | Numerical Value - Monthly Salary                                                                                                                               |
# | 19 | MonthlyRate                | Numerical Value - Monthly Rate                                                                                                                                  |
# | 20 | NumCompaniesWorked        | Numerical Value - Number of companies worked at                                                                                                                |
# | 21 | Over18                    | Text - Y                                                                                                                                                    |
# | 22 | Overtime                   | Text - No, Yes                                                                                                                                                    |
# | 23 | PercentSalaryHike        | Numerical Value - Percentage increase in salary                                                                                                                |
# | 24 | PerformanceRating         | Numerical Value - 1=Low, 2=Good, 3=Excellent, 4=Outstanding                                                                                                    |
# | 25 | RelationshipSatisfaction  | Numerical Value - 1=Low, 2=Medium, 3=High, 4=Very High                                                                                                         |
# | 26 | StandardHours             | Numerical Value - 80                                                                                                                                            |
# | 27 | StockOptionsLevel        | Numerical Value - 0, 1, 2, 3                                                                                                                                    |
# | 28 | TotalWorkingYears        | Numerical Value - Total years worked                                                                                                                            |
# | 29 | TrainingTimesLastYear   | Numerical Value - How many times the employee has been trained last year                                                                                       |
# | 30 | WorkLifeBalance          | Numerical Value - 1=Bad, 2=Good, 3=Better, 4=Best                                                                                                              |
# | 31 | YearsAtCompany           | Numerical Value - Number of years at the company                                                                                                                |
# | 32 | YearsInCurrentRole      | Numerical Value -Number of years in current role                                                                                                                |
# | 33 | YearsSinceLastPromotion | Numerical Value - Years since last promotion                                                                                                                    |
# | 34 | YearsWithCurrManager | Numerical Value - Years with current manager                                                                                                                    |

# %% [markdown]
# ## Checagens básicas

# %% [markdown]
# - shape
# - colunas
# - tipos
# - valores nulos
# - valores "estranhos"
# - valores únicos
# - valores duplicados
# - contagem de valores relevantes

# %%
import pandas as pd

BASE = "ibm.csv"
df_ibm = pd.read_csv(BASE)
df_ibm.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
#Visualizar mais colunas
with pd.option_context('display.max_columns',35):
    display(df_ibm.head())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
df_ibm.shape
# Out:
# (1470, 35)

# %%
df_ibm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
with pd.option_context('float_format','{:.2f}'.format,"display.max_columns",35):
    display(df_ibm.describe())
# Out:
#           Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# count 1470.00    1470.00           1470.00    1470.00        1470.00
# mean    36.92     802.49              9.19       2.91           1.00
# std      9.14     403.51              8.11       1.02           0.00
# min     18.00     102.00              1.00       1.00           1.00
# 25%     30.00     465.00              2.00       2.00           1.00
# 50%     36.00     802.00              7.00       3.00           1.00
# 75%     43.00    1157.00             14.00       4.00           1.00
# max     60.00    1499.00             29.00       5.00           1.00
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count         1470.00                  1470.00     1470.00         1470.00
# mean          1024.87                     2.72       65.89            2.73
# std            602.02                     1.09       20.33            0.71
# min              1.00                     1.00       30.00            1.00
# 25%            491.25                     2.00       48.00            2.00
# 50%           1020.50                     3.00       66.00            3.00
# 75%           1555.75                     4.00       83.75            3.00
# max           2068.00                     4.00      100.00            4.00
#
#        JobLevel  JobSatisfaction  MonthlyIncome  MonthlyRate  \
# count   1470.00          1470.00        1470.00      1470.00
# mean       2.06             2.73        6502.93     14313.10
# std        1.11             1.10        4707.96      7117.79
# min        1.00             1.00        1009.00      2094.00
# 25%        1.00             2.00        2911.00      8047.00
# 50%        2.00             3.00        4919.00     14235.50
# 75%        3.00             4.00        8379.00     20461.50
# max        5.00             4.00       19999.00     26999.00
#
#        NumCompaniesWorked  PercentSalaryHike  PerformanceRating  \
# count             1470.00            1470.00            1470.00
# mean                 2.69              15.21               3.15
# std                  2.50               3.66               0.36
# min                  0.00              11.00               3.00
# 25%                  1.00              12.00               3.00
# 50%                  2.00              14.00               3.00
# 75%                  4.00              18.00               3.00
# max                  9.00              25.00               4.00
#
#        RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# count                   1470.00        1470.00           1470.00
# mean                       2.71          80.00              0.79
# std                        1.08           0.00              0.85
# min                        1.00          80.00              0.00
# 25%                        2.00          80.00              0.00
# 50%                        3.00          80.00              1.00
# 75%                        4.00          80.00              1.00
# max                        4.00          80.00              3.00
#
#        TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# count            1470.00                1470.00          1470.00
# mean               11.28                   2.80             2.76
# std                 7.78                   1.29             0.71
# min                 0.00                   0.00             1.00
# 25%                 6.00                   2.00             2.00
# 50%                10.00                   3.00             3.00
# 75%                15.00                   3.00             3.00
# max                40.00                   6.00             4.00
#
#        YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# count         1470.00             1470.00                  1470.00
# mean             7.01                4.23                     2.19
# std              6.13                3.62                     3.22
# min              0.00                0.00                     0.00
# 25%              3.00                2.00                     0.00
# 50%              5.00                3.00                     1.00
# 75%              9.00                7.00                     3.00
# max             40.00               18.00                    15.00
#
#        YearsWithCurrManager
# count               1470.00
# mean                   4.12
# std                    3.57
# min                    0.00
# 25%                    2.00
# 50%                    3.00
# 75%                    7.00
# max                   17.00

# %%
# Esta analisando quartil, como funciona 
# 1.5 * (75% - 25%)
# Depois disso faz subtração do 25%
# Soma do 75%.
25 - 1.5 * (43 - 30)
43 + 1.5 * (43 - 30)
# Out:
# 62.5

# %%
df_ibm.describe(exclude='number')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df_ibm.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Removendo coluna desnecessarias

df_sem_nulo = df_ibm.drop(['Over18','EmployeeNumber','EmployeeCount','StandardHours'],axis=1)

# %%
df_sem_nulo.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0  Female  ...                  3                         1                 0
# 1    Male  ...                  4                         4                 1
# 2    Male  ...                  3                         2                 0
# 3  Female  ...                  3                         3                 0
# 4    Male  ...                  3                         4                 1
#
#   TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 8                      0               1               6
# 1                10                      3               3              10
# 2                 7                      3               3               0
# 3                 8                      3               3               8
# 4                 6                      3               3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                   4                        0                    5
# 1                   7                        1                    7
# 2                   0                        0                    0
# 3                   7                        3                    0
# 4                   2                        2                    2
#
# [5 rows x 31 columns]

# %%
#Vendo os funcionarios mas velho e mas novos 10 funcionarios

mais_velhos = df_sem_nulo.nlargest(10,"Age")
mais_novos = df_sem_nulo.nsmallest(10,"Age")

# Mas tempo na empresa
mais_velho_empresa = df_sem_nulo.nlargest(10,"YearsAtCompany")
mais_novos_empresa = df_sem_nulo.nlargest(10,"YearsAtCompany")

# Temp de promoção
mais_tempo_promocao = df_sem_nulo.nlargest(10,"YearsSinceLastPromotion")
menos_tempo_promocao = df_sem_nulo.nlargest(10,"YearsSinceLastPromotion")


display(mais_velhos)
display(mais_novos)
display(mais_velho_empresa)
display(mais_novos_empresa)
display(mais_tempo_promocao)
display(menos_tempo_promocao)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 411    60        No      Travel_Rarely        422  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 536    60        No      Travel_Rarely       1179                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 63     59        No      Travel_Rarely       1435                   Sales
# 70     59        No  Travel_Frequently       1225                   Sales
# 105    59        No         Non-Travel       1420         Human Resources
# 225    59        No      Travel_Rarely        142  Research & Development
#
#       DistanceFromHome  Education   EducationField  EnvironmentSatisfaction  \
# 411                  7          3    Life Sciences                        1
# 427                 28          3        Marketing                        3
# 536                 16          4        Marketing                        1
# 879                  7          4        Marketing                        2
# 1209                 1          4          Medical                        3
# 6                    3          3          Medical                        3
# 63                  25          3    Life Sciences                        1
# 70                   1          1    Life Sciences                        1
# 105                  2          4  Human Resources                        3
# 225                  3          3    Life Sciences                        3
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 411   Female  ...                  3                         4
# 427   Female  ...                  3                         4
# 536     Male  ...                  3                         4
# 879     Male  ...                  3                         2
# 1209    Male  ...                  4                         3
# 6     Female  ...                  4                         1
# 63    Female  ...                  3                         4
# 70    Female  ...                  3                         4
# 105   Female  ...                  4                         4
# 225     Male  ...                  3                         1
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 411                  0                33                      5
# 427                  0                22                      5
# 536                  0                10                      1
# 879                  1                12                      3
# 1209                 1                19                      2
# 6                    3                12                      3
# 63                   0                28                      3
# 70                   0                20                      2
# 105                  1                30                      3
# 225                  1                 7                      6
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 411                1              29                   8
# 427                4              18                  13
# 536                3               2                   2
# 879                3              11                   7
# 1209               4               1                   0
# 6                  2               1                   0
# 63                 2              21                  16
# 70                 2               4                   3
# 105                3               3                   2
# 225                3               1                   0
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 411                        11                   10
# 427                        13                   11
# 536                         2                    2
# 879                         1                    9
# 1209                        0                    0
# 6                           0                    0
# 63                          7                    9
# 70                          1                    3
# 105                         2                    2
# 225                         0                    0
#
# [10 rows x 31 columns]
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 296    18       Yes      Travel_Rarely        230  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 727    18        No         Non-Travel        287  Research & Development
# 828    18       Yes         Non-Travel        247  Research & Development
# 972    18        No         Non-Travel       1124  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
# 1311   18        No         Non-Travel       1431  Research & Development
# 127    19       Yes      Travel_Rarely        528                   Sales
# 149    19        No      Travel_Rarely       1181  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 296                  3          3  Life Sciences                        3
# 301                 10          3        Medical                        4
# 457                  5          3      Marketing                        2
# 727                  5          2  Life Sciences                        2
# 828                  8          1        Medical                        3
# 972                  1          3  Life Sciences                        4
# 1153                 3          2        Medical                        2
# 1311                14          3        Medical                        2
# 127                 22          1      Marketing                        4
# 149                  3          1        Medical                        2
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 296     Male  ...                  3                         3
# 301   Female  ...                  3                         1
# 457     Male  ...                  3                         4
# 727     Male  ...                  3                         4
# 828     Male  ...                  3                         4
# 972   Female  ...                  3                         3
# 1153  Female  ...                  3                         3
# 1311  Female  ...                  3                         3
# 127     Male  ...                  3                         4
# 149   Female  ...                  3                         4
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 296                  0                 0                      2
# 301                  0                 0                      2
# 457                  0                 0                      3
# 727                  0                 0                      2
# 828                  0                 0                      0
# 972                  0                 0                      5
# 1153                 0                 0                      2
# 1311                 0                 0                      4
# 127                  0                 0                      2
# 149                  0                 1                      3
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 296                3               0                   0
# 301                3               0                   0
# 457                3               0                   0
# 727                3               0                   0
# 828                3               0                   0
# 972                4               0                   0
# 1153               4               0                   0
# 1311               1               0                   0
# 127                2               0                   0
# 149                3               1                   0
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 296                         0                    0
# 301                         0                    0
# 457                         0                    0
# 727                         0                    0
# 828                         0                    0
# 972                         0                    0
# 1153                        0                    0
# 1311                        0                    0
# 127                         0                    0
# 149                         0                    0
#
# [10 rows x 31 columns]
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 126    58       Yes  Travel_Rarely        147  Research & Development
# 98     58        No  Travel_Rarely        682                   Sales
# 270    55        No  Travel_Rarely        452  Research & Development
# 1116   55        No  Travel_Rarely        685                   Sales
# 561    52        No  Travel_Rarely        621                   Sales
# 190    52        No  Travel_Rarely        699  Research & Development
# 237    52        No     Non-Travel        771                   Sales
# 914    55        No     Non-Travel        177  Research & Development
# 962    51        No  Travel_Rarely        770         Human Resources
# 1111   53       Yes  Travel_Rarely        607  Research & Development
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 126                 23          4           Medical                        4
# 98                  10          4           Medical                        4
# 270                  1          3           Medical                        4
# 1116                26          5         Marketing                        3
# 561                  3          4         Marketing                        3
# 190                  1          4     Life Sciences                        3
# 237                  2          4     Life Sciences                        1
# 914                  8          1           Medical                        4
# 962                  5          3     Life Sciences                        3
# 1111                 2          5  Technical Degree                        3
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 126   Female  ...                  3                         4
# 98      Male  ...                  3                         3
# 270     Male  ...                  3                         3
# 1116    Male  ...                  4                         3
# 561     Male  ...                  3                         1
# 190     Male  ...                  3                         1
# 237     Male  ...                  3                         4
# 914     Male  ...                  3                         4
# 962     Male  ...                  3                         2
# 1111  Female  ...                  3                         2
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 126                  1                40                      3
# 98                   0                38                      1
# 270                  0                37                      2
# 1116                 1                36                      3
# 561                  0                34                      3
# 190                  1                34                      5
# 237                  0                33                      2
# 914                  1                34                      3
# 962                  1                33                      2
# 1111                 1                34                      4
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 126                2              40                  10
# 98                 2              37                  10
# 270                3              36                  10
# 1116               3              36                   6
# 561                4              34                   6
# 190                3              33                  18
# 237                4              33                   7
# 914                3              33                   9
# 962                3              33                   9
# 1111               3              33                   7
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 126                        15                    6
# 98                          1                    8
# 270                         4                   13
# 1116                        2                   13
# 561                         1                   16
# 190                        11                    9
# 237                        15                   12
# 914                        15                    0
# 962                         0                   10
# 1111                        1                    9
#
# [10 rows x 31 columns]
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 126    58       Yes  Travel_Rarely        147  Research & Development
# 98     58        No  Travel_Rarely        682                   Sales
# 270    55        No  Travel_Rarely        452  Research & Development
# 1116   55        No  Travel_Rarely        685                   Sales
# 561    52        No  Travel_Rarely        621                   Sales
# 190    52        No  Travel_Rarely        699  Research & Development
# 237    52        No     Non-Travel        771                   Sales
# 914    55        No     Non-Travel        177  Research & Development
# 962    51        No  Travel_Rarely        770         Human Resources
# 1111   53       Yes  Travel_Rarely        607  Research & Development
#
#       DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 126                 23          4           Medical                        4
# 98                  10          4           Medical                        4
# 270                  1          3           Medical                        4
# 1116                26          5         Marketing                        3
# 561                  3          4         Marketing                        3
# 190                  1          4     Life Sciences                        3
# 237                  2          4     Life Sciences                        1
# 914                  8          1           Medical                        4
# 962                  5          3     Life Sciences                        3
# 1111                 2          5  Technical Degree                        3
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 126   Female  ...                  3                         4
# 98      Male  ...                  3                         3
# 270     Male  ...                  3                         3
# 1116    Male  ...                  4                         3
# 561     Male  ...                  3                         1
# 190     Male  ...                  3                         1
# 237     Male  ...                  3                         4
# 914     Male  ...                  3                         4
# 962     Male  ...                  3                         2
# 1111  Female  ...                  3                         2
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 126                  1                40                      3
# 98                   0                38                      1
# 270                  0                37                      2
# 1116                 1                36                      3
# 561                  0                34                      3
# 190                  1                34                      5
# 237                  0                33                      2
# 914                  1                34                      3
# 962                  1                33                      2
# 1111                 1                34                      4
#
#      WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 126                2              40                  10
# 98                 2              37                  10
# 270                3              36                  10
# 1116               3              36                   6
# 561                4              34                   6
# 190                3              33                  18
# 237                4              33                   7
# 914                3              33                   9
# 962                3              33                   9
# 1111               3              33                   7
#
#       YearsSinceLastPromotion YearsWithCurrManager
# 126                        15                    6
# 98                          1                    8
# 270                         4                   13
# 1116                        2                   13
# 561                         1                   16
# 190                        11                    9
# 237                        15                   12
# 914                        15                    0
# 962                         0                   10
# 1111                        1                    9
#
# [10 rows x 31 columns]
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 45    41       Yes  Travel_Rarely       1360  Research & Development
# 123   51        No  Travel_Rarely        684  Research & Development
# 126   58       Yes  Travel_Rarely        147  Research & Development
# 178   46        No  Travel_Rarely        526                   Sales
# 237   52        No     Non-Travel        771                   Sales
# 425   50        No  Travel_Rarely       1099  Research & Development
# 701   53        No  Travel_Rarely       1376                   Sales
# 752   36       Yes  Travel_Rarely        885  Research & Development
# 861   46        No  Travel_Rarely       1402                   Sales
# 914   55        No     Non-Travel        177  Research & Development
#
#      DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 45                 12          3  Technical Degree                        2
# 123                 6          3     Life Sciences                        1
# 126                23          4           Medical                        4
# 178                 1          2         Marketing                        2
# 237                 2          4     Life Sciences                        1
# 425                29          4     Life Sciences                        2
# 701                 2          2           Medical                        3
# 752                16          4     Life Sciences                        3
# 861                 2          3         Marketing                        3
# 914                 8          1           Medical                        4
#
#      Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 45   Female  ...                  3                         4
# 123    Male  ...                  3                         3
# 126  Female  ...                  3                         4
# 178  Female  ...                  4                         3
# 237    Male  ...                  3                         4
# 425    Male  ...                  3                         2
# 701    Male  ...                  3                         3
# 752  Female  ...                  3                         3
# 861  Female  ...                  4                         1
# 914    Male  ...                  3                         4
#
#      StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 45                  0                23                      0
# 123                 0                23                      5
# 126                 1                40                      3
# 178                 3                24                      2
# 237                 0                33                      2
# 425                 1                28                      2
# 701                 1                22                      3
# 752                 0                18                      1
# 861                 0                28                      2
# 914                 1                34                      3
#
#     WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 45                3              22                  15
# 123               3              20                  18
# 126               2              40                  10
# 178               3              24                  13
# 237               4              33                   7
# 425               3              27                  10
# 701               4              17                  13
# 752               3              17                  13
# 861               3              26                  15
# 914               3              33                   9
#
#      YearsSinceLastPromotion YearsWithCurrManager
# 45                        15                    8
# 123                       15                   15
# 126                       15                    6
# 178                       15                    7
# 237                       15                   12
# 425                       15                    7
# 701                       15                    2
# 752                       15                   14
# 861                       15                    9
# 914                       15                    0
#
# [10 rows x 31 columns]
#      Age Attrition BusinessTravel  DailyRate              Department  \
# 45    41       Yes  Travel_Rarely       1360  Research & Development
# 123   51        No  Travel_Rarely        684  Research & Development
# 126   58       Yes  Travel_Rarely        147  Research & Development
# 178   46        No  Travel_Rarely        526                   Sales
# 237   52        No     Non-Travel        771                   Sales
# 425   50        No  Travel_Rarely       1099  Research & Development
# 701   53        No  Travel_Rarely       1376                   Sales
# 752   36       Yes  Travel_Rarely        885  Research & Development
# 861   46        No  Travel_Rarely       1402                   Sales
# 914   55        No     Non-Travel        177  Research & Development
#
#      DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 45                 12          3  Technical Degree                        2
# 123                 6          3     Life Sciences                        1
# 126                23          4           Medical                        4
# 178                 1          2         Marketing                        2
# 237                 2          4     Life Sciences                        1
# 425                29          4     Life Sciences                        2
# 701                 2          2           Medical                        3
# 752                16          4     Life Sciences                        3
# 861                 2          3         Marketing                        3
# 914                 8          1           Medical                        4
#
#      Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# 45   Female  ...                  3                         4
# 123    Male  ...                  3                         3
# 126  Female  ...                  3                         4
# 178  Female  ...                  4                         3
# 237    Male  ...                  3                         4
# 425    Male  ...                  3                         2
# 701    Male  ...                  3                         3
# 752  Female  ...                  3                         3
# 861  Female  ...                  4                         1
# 914    Male  ...                  3                         4
#
#      StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 45                  0                23                      0
# 123                 0                23                      5
# 126                 1                40                      3
# 178                 3                24                      2
# 237                 0                33                      2
# 425                 1                28                      2
# 701                 1                22                      3
# 752                 0                18                      1
# 861                 0                28                      2
# 914                 1                34                      3
#
#     WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 45                3              22                  15
# 123               3              20                  18
# 126               2              40                  10
# 178               3              24                  13
# 237               4              33                   7
# 425               3              27                  10
# 701               4              17                  13
# 752               3              17                  13
# 861               3              26                  15
# 914               3              33                   9
#
#      YearsSinceLastPromotion YearsWithCurrManager
# 45                        15                    8
# 123                       15                   15
# 126                       15                    6
# 178                       15                    7
# 237                       15                   12
# 425                       15                    7
# 701                       15                    2
# 752                       15                   14
# 861                       15                    9
# 914                       15                    0
#
# [10 rows x 31 columns]

# %%
df_sem_nulo.nlargest(10,"YearsSinceLastPromotion")[['Age','JobRole','YearsSinceLastPromotion','JobLevel', "Department"]]
# Out:
#      Age                    JobRole  YearsSinceLastPromotion  JobLevel  \
# 45    41          Research Director                       15         5
# 123   51          Research Director                       15         5
# 126   58  Healthcare Representative                       15         3
# 178   46            Sales Executive                       15         3
# 237   52                    Manager                       15         5
# 425   50                    Manager                       15         4
# 701   53                    Manager                       15         4
# 752   36      Laboratory Technician                       15         1
# 861   46                    Manager                       15         4
# 914   55  Healthcare Representative                       15         4
#
#                  Department
# 45   Research & Development
# 123  Research & Development
# 126  Research & Development
# 178                   Sales
# 237                   Sales
# 425  Research & Development
# 701                   Sales
# 752  Research & Development
# 861                   Sales
# 914  Research & Development

# %%
df_sem_nulo.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
colunas_categoricas_nao_ordenadas =[
    'BusinessTravel',
    'Department',
    'EducationField',
    'Gender',
    'JobRole',
    'MaritalStatus',
    'OverTime',
]

colunas_categoricas_ordenadas = [
    'Education',
    'EnvironmentSatisfaction',
    'JobSatisfaction',
    'JobInvolvement',
    'JobLevel',
    'PerformanceRating',
    'RelationshipSatisfaction',
    'StockOptionLevel',
    'WorkLifeBalance',
]

coluna_alvo =['Attrition']

colunas_numericas = [ 
    coluna for coluna in df_sem_nulo.columns  if coluna not in (
        colunas_categoricas_nao_ordenadas + colunas_categoricas_ordenadas + coluna_alvo
        )
        
        ]

# %%
colunas_numericas
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'HourlyRate',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
for coluna in (colunas_categoricas_ordenadas + colunas_categoricas_nao_ordenadas):
    print(f'{coluna} : {df_sem_nulo[coluna].unique()}')
# Out:
# Education : [2 1 4 3 5]
# EnvironmentSatisfaction : [2 3 4 1]
# JobSatisfaction : [4 2 3 1]
# JobInvolvement : [3 2 4 1]
# JobLevel : [2 1 3 4 5]
# PerformanceRating : [3 4]
# RelationshipSatisfaction : [1 4 2 3]
# StockOptionLevel : [0 1 3 2]
# WorkLifeBalance : [1 3 2 4]
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department : ['Sales' 'Research & Development' 'Human Resources']
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Gender : ['Female' 'Male']
# JobRole : ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# MaritalStatus : ['Single' 'Married' 'Divorced']
# OverTime : ['Yes' 'No']

# %%
df_sem_nulo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
#  14  JobSatisfaction           1470 non-null   int64
#  15  MaritalStatus             1470 non-null   object
#  16  MonthlyIncome             1470 non-null   int64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1470 non-null   object
#  20  PercentSalaryHike         1470 non-null   int64
#  21  PerformanceRating         1470 non-null   int64
#  22  RelationshipSatisfaction  1470 non-null   int64
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1470 non-null   int64
#  26  WorkLifeBalance           1470 non-null   int64
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(23), object(8)
# memory usage: 356.1+ KB

# %%
for coluna in colunas_categoricas_nao_ordenadas:
    df_sem_nulo[coluna] =df_sem_nulo[coluna].astype('category')

# %%
df_sem_nulo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   category
#  14  JobSatisfaction           1470 non-null   int64
#  15  MaritalStatus             1470 non-null   category
#  16  MonthlyIncome             1470 non-null   int64
#  17  MonthlyRate               1470 non-null   int64
#  18  NumCompaniesWorked        1470 non-null   int64
#  19  OverTime                  1470 non-null   category
#  20  PercentSalaryHike         1470 non-null   int64
#  21  PerformanceRating         1470 non-null   int64
#  22  RelationshipSatisfaction  1470 non-null   int64
#  23  StockOptionLevel          1470 non-null   int64
#  24  TotalWorkingYears         1470 non-null   int64
#  25  TrainingTimesLastYear     1470 non-null   int64
#  26  WorkLifeBalance           1470 non-null   int64
#  27  YearsAtCompany            1470 non-null   int64
#  28  YearsInCurrentRole        1470 non-null   int64
#  29  YearsSinceLastPromotion   1470 non-null   int64
#  30  YearsWithCurrManager      1470 non-null   int64
# dtypes: category(7), int64(23), object(1)
# memory usage: 287.0+ KB

# %%
for coluna in df_sem_nulo.select_dtypes(include='category'):
    print(f'{coluna}')
    print(f'{coluna}.cat.categories: {df_sem_nulo[coluna].cat.categories}')
    print(f'{coluna}.cat.ordered: {df_sem_nulo[coluna].cat.ordered}')
    print(f'{coluna}.cat.codes: {df_sem_nulo[coluna].cat.codes.unique()}')
    print()
# Out:
# BusinessTravel
# BusinessTravel.cat.categories: Index(['Non-Travel', 'Travel_Frequently', 'Travel_Rarely'], dtype='object')
# BusinessTravel.cat.ordered: False
# BusinessTravel.cat.codes: [2 1 0]
#
# Department
# Department.cat.categories: Index(['Human Resources', 'Research & Development', 'Sales'], dtype='object')
# Department.cat.ordered: False
# Department.cat.codes: [2 1 0]
#
# EducationField
# EducationField.cat.categories: Index(['Human Resources', 'Life Sciences', 'Marketing', 'Medical', 'Other',
#        'Technical Degree'],
#       dtype='object')
# EducationField.cat.ordered: False
# EducationField.cat.codes: [1 4 3 2 5 0]
#
# Gender
# Gender.cat.categories: Index(['Female', 'Male'], dtype='object')
# Gender.cat.ordered: False
# Gender.cat.codes: [0 1]
#
# JobRole
# JobRole.cat.categories: Index(['Healthcare Representative', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
#        'Research Scientist', 'Sales Executive', 'Sales Representative'],
#       dtype='object')
# JobRole.cat.ordered: False
# JobRole.cat.codes: [7 6 2 4 0 3 8 5 1]
#
# MaritalStatus
# MaritalStatus.cat.categories: Index(['Divorced', 'Married', 'Single'], dtype='object')
# MaritalStatus.cat.ordered: False
# MaritalStatus.cat.codes: [2 1 0]
#
# OverTime
# OverTime.cat.categories: Index(['No', 'Yes'], dtype='object')
# OverTime.cat.ordered: False
# OverTime.cat.codes: [1 0]

# %%
df_sem_nulo['Attrition'].value_counts().plot(kind='bar');

# %%
df_sem_nulo['Attrition'].value_counts().plot(kind='bar', color = ['blue','red']);

# %%
df_sem_nulo['Attrition'].value_counts(normalize=True).plot(kind='bar');

# %%
df_sem_nulo['Department'].value_counts().plot(kind='bar');

# %%
df_sem_nulo.groupby(["Department", 'Attrition']).size()
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\621298995.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo.groupby(["Department", 'Attrition']).size()
# Department              Attrition
# Human Resources         No            51
#                         Yes           12
# Research & Development  No           828
#                         Yes          133
# Sales                   No           354
#                         Yes           92
# dtype: int64

# %%
df_sem_nulo.pivot_table(index="Department", columns='Attrition',aggfunc='size')
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\867407194.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df_sem_nulo.pivot_table(index="Department", columns='Attrition',aggfunc='size')
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
pd.crosstab(df_sem_nulo["Department"],df_sem_nulo['Attrition'])
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
pd.crosstab(df_sem_nulo["Department"],df_sem_nulo['Attrition'], normalize="index")*100
# Out:
# Attrition                      No        Yes
# Department
# Human Resources         80.952381  19.047619
# Research & Development  86.160250  13.839750
# Sales                   79.372197  20.627803

# %%
pd.crosstab(df_sem_nulo["Department"],df_sem_nulo['Attrition'], normalize="columns")*100
# Out:
# Attrition                      No        Yes
# Department
# Human Resources          4.136253   5.063291
# Research & Development  67.153285  56.118143
# Sales                   28.710462  38.818565

# %% [markdown]
# Colormaps :https://matplotlib.org/stable/users/explain/colors/colormaps.html

# %%
pd.crosstab(df_sem_nulo["Department"],df_sem_nulo['Attrition'], normalize="index").style.background_gradient(cmap="RdYlGn",axis='columns')
# Out:
# <style type="text/css">
# #T_c6856_row0_col0, #T_c6856_row1_col0, #T_c6856_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_c6856_row0_col1, #T_c6856_row1_col1, #T_c6856_row2_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c6856">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_c6856_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_c6856_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6856_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_c6856_row0_col0" class="data row0 col0" >0.809524</td>
#       <td id="T_c6856_row0_col1" class="data row0 col1" >0.190476</td>
#     </tr>
#     <tr>
#       <th id="T_c6856_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_c6856_row1_col0" class="data row1 col0" >0.861602</td>
#       <td id="T_c6856_row1_col1" class="data row1 col1" >0.138398</td>
#     </tr>
#     <tr>
#       <th id="T_c6856_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_c6856_row2_col0" class="data row2 col0" >0.793722</td>
#       <td id="T_c6856_row2_col1" class="data row2 col1" >0.206278</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab(df_sem_nulo["Department"],df_sem_nulo['Attrition'], margins=True,margins_name="Total")
# Out:
# Attrition                 No  Yes  Total
# Department
# Human Resources           51   12     63
# Research & Development   828  133    961
# Sales                    354   92    446
# Total                   1233  237   1470

# %%
pd.crosstab(df_sem_nulo["Department"],df_sem_nulo['Attrition']).plot(kind='bar');

# %%
pd.crosstab(df_sem_nulo['Department'],df_sem_nulo['Gender'],margins=True,margins_name='Total')
# Out:
# Gender                  Female  Male  Total
# Department
# Human Resources             20    43     63
# Research & Development     379   582    961
# Sales                      189   257    446
# Total                      588   882   1470

# %%
df_sem_nulo.pivot_table(index=['Department','Gender'], columns='Attrition',aggfunc='size')
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\3449640860.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df_sem_nulo.pivot_table(index=['Department','Gender'], columns='Attrition',aggfunc='size')
# Attrition                       No  Yes
# Department             Gender
# Human Resources        Female   14    6
#                        Male     37    6
# Research & Development Female  336   43
#                        Male    492   90
# Sales                  Female  151   38
#                        Male    203   54

# %%
df_sem_nulo.pivot_table(index=['JobRole','Gender'], columns='Attrition',aggfunc='size')
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\613489825.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df_sem_nulo.pivot_table(index=['JobRole','Gender'], columns='Attrition',aggfunc='size')
# Attrition                          No  Yes
# JobRole                   Gender
# Healthcare Representative Female   46    5
#                           Male     76    4
# Human Resources           Female   10    6
#                           Male     30    6
# Laboratory Technician     Female   69   16
#                           Male    128   46
# Manager                   Female   45    2
#                           Male     52    3
# Manufacturing Director    Female   68    4
#                           Male     67    6
# Research Director         Female   32    1
#                           Male     46    1
# Research Scientist        Female   97   17
#                           Male    148   30
# Sales Executive           Female  112   20
#                           Male    157   37
# Sales Representative      Female   22   16
#                           Male     28   17

# %%
df_sem_nulo.groupby('Education')['MonthlyIncome'].mean()
# Out:
# Education
# 1    5640.570588
# 2    6226.645390
# 3    6517.263986
# 4    6832.402010
# 5    8277.645833
# Name: MonthlyIncome, dtype: float64

# %%
mapeamento_educacao ={
    1:'Below College',
    2:'College',
    3:'Bachelor',
    4:'Master',
    5:'PhD',
}

# %%
df_sem_nulo.groupby('Education')['MonthlyIncome'].mean().rename(index=mapeamento_educacao)
# Out:
# Education
# Below College    5640.570588
# College          6226.645390
# Bachelor         6517.263986
# Master           6832.402010
# PhD              8277.645833
# Name: MonthlyIncome, dtype: float64

# %%
df_sem_nulo.groupby('Education').size().rename(index=mapeamento_educacao)
# Out:
# Education
# Below College    170
# College          282
# Bachelor         572
# Master           398
# PhD               48
# dtype: int64

# %%
df_sem_nulo.groupby(['Education','Attrition']).size().rename(index=mapeamento_educacao)
# Out:
# Education      Attrition
# Below College  No           139
#                Yes           31
# College        No           238
#                Yes           44
# Bachelor       No           473
#                Yes           99
# Master         No           340
#                Yes           58
# PhD            No            43
#                Yes            5
# dtype: int64

# %%
pd.crosstab(df_sem_nulo['Education'],df_sem_nulo['Attrition'],margins=True,margins_name="Total").rename(index=mapeamento_educacao)
# Out:
# Attrition        No  Yes  Total
# Education
# Below College   139   31    170
# College         238   44    282
# Bachelor        473   99    572
# Master          340   58    398
# PhD              43    5     48
# Total          1233  237   1470

# %%
pd.crosstab(
    df_sem_nulo['Education'],
    df_sem_nulo['Attrition'],
    margins=True,margins_name="Total",
    normalize='index'
    ).rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# Attrition         No    Yes
# Education
# Below College  81.76  18.24
# College        84.40  15.60
# Bachelor       82.69  17.31
# Master         85.43  14.57
# PhD            89.58  10.42
# Total          83.88  16.12

# %%
pd.crosstab(
    df_sem_nulo['Education'],
    df_sem_nulo['Attrition'],
    margins=True,margins_name="Total",
    normalize='columns'
    ).rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# Attrition         No    Yes  Total
# Education
# Below College  11.27  13.08  11.56
# College        19.30  18.57  19.18
# Bachelor       38.36  41.77  38.91
# Master         27.58  24.47  27.07
# PhD             3.49   2.11   3.27

# %%
pd.crosstab(
    df_sem_nulo['Education'],
    df_sem_nulo['Department'],
    margins=True,margins_name="Total",
        ).rename(index=mapeamento_educacao)
# Out:
# Department     Human Resources  Research & Development  Sales  Total
# Education
# Below College                5                     115     50    170
# College                     13                     182     87    282
# Bachelor                    27                     379    166    572
# Master                      15                     255    128    398
# PhD                          3                      30     15     48
# Total                       63                     961    446   1470

# %%
pd.crosstab(
    df_sem_nulo['Education'],
    df_sem_nulo['JobRole'],
    margins=True,margins_name="Total",
        ).rename(index=mapeamento_educacao)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below College                         15                5
# College                               21               12
# Bachelor                              48               22
# Master                                44               10
# PhD                                    3                3
# Total                                131               52
#
# JobRole        Laboratory Technician  Manager  Manufacturing Director  \
# Education
# Below College                     35        9                      15
# College                           57       19                      33
# Bachelor                         104       40                      54
# Master                            58       29                      38
# PhD                                5        5                       5
# Total                            259      102                     145
#
# JobRole        Research Director  Research Scientist  Sales Executive  \
# Education
# Below College                  7                  37               27
# College                       13                  46               66
# Bachelor                      30                 122              120
# Master                        23                  79              101
# PhD                            7                   8               12
# Total                         80                 292              326
#
# JobRole        Sales Representative  Total
# Education
# Below College                    20    170
# College                          15    282
# Bachelor                         32    572
# Master                           16    398
# PhD                               0     48
# Total                            83   1470

# %%
pd.crosstab(
    df_sem_nulo['Education'],
    df_sem_nulo['JobRole'],
    margins=True,margins_name="Total",
    normalize="index"
        ).rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below College                       8.82             2.94
# College                             7.45             4.26
# Bachelor                            8.39             3.85
# Master                             11.06             2.51
# PhD                                 6.25             6.25
# Total                               8.91             3.54
#
# JobRole        Laboratory Technician  Manager  Manufacturing Director  \
# Education
# Below College                  20.59     5.29                    8.82
# College                        20.21     6.74                   11.70
# Bachelor                       18.18     6.99                    9.44
# Master                         14.57     7.29                    9.55
# PhD                            10.42    10.42                   10.42
# Total                          17.62     6.94                    9.86
#
# JobRole        Research Director  Research Scientist  Sales Executive  \
# Education
# Below College               4.12               21.76            15.88
# College                     4.61               16.31            23.40
# Bachelor                    5.24               21.33            20.98
# Master                      5.78               19.85            25.38
# PhD                        14.58               16.67            25.00
# Total                       5.44               19.86            22.18
#
# JobRole        Sales Representative
# Education
# Below College                 11.76
# College                        5.32
# Bachelor                       5.59
# Master                         4.02
# PhD                            0.00
# Total                          5.65

# %%
pd.crosstab(
    df_sem_nulo['Education'],
    df_sem_nulo['JobRole'],
    margins=True,
    margins_name="Total",
    normalize='columns'
        ).rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below College                      11.45             9.62
# College                            16.03            23.08
# Bachelor                           36.64            42.31
# Master                             33.59            19.23
# PhD                                 2.29             5.77
#
# JobRole        Laboratory Technician  Manager  Manufacturing Director  \
# Education
# Below College                  13.51     8.82                   10.34
# College                        22.01    18.63                   22.76
# Bachelor                       40.15    39.22                   37.24
# Master                         22.39    28.43                   26.21
# PhD                             1.93     4.90                    3.45
#
# JobRole        Research Director  Research Scientist  Sales Executive  \
# Education
# Below College               8.75               12.67             8.28
# College                    16.25               15.75            20.25
# Bachelor                   37.50               41.78            36.81
# Master                     28.75               27.05            30.98
# PhD                         8.75                2.74             3.68
#
# JobRole        Sales Representative  Total
# Education
# Below College                 24.10  11.56
# College                       18.07  19.18
# Bachelor                      38.55  38.91
# Master                        19.28  27.07
# PhD                            0.00   3.27

# %%
pd.crosstab(
    df_sem_nulo['Education'],
    df_sem_nulo['JobLevel'],
    margins=True,
    margins_name="Total",
    normalize='columns'
        ).rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# JobLevel           1      2      3      4      5  Total
# Education
# Below College  16.39   8.80   9.17   7.55   8.70  11.56
# College        17.31  23.41  15.14  16.04  18.84  19.18
# Bachelor       42.54  32.02  44.95  41.51  40.58  38.91
# Master         22.28  32.02  26.61  26.42  28.99  27.07
# PhD             1.47   3.75   4.13   8.49   2.90   3.27

# %%
pd.crosstab(
    df_sem_nulo['Education'],
    df_sem_nulo['JobRole'],
    margins=True,
    margins_name="Total",
    normalize='index'
        ).rename(index=mapeamento_educacao).mul(100).round(2)
# Out:
# JobRole        Healthcare Representative  Human Resources  \
# Education
# Below College                       8.82             2.94
# College                             7.45             4.26
# Bachelor                            8.39             3.85
# Master                             11.06             2.51
# PhD                                 6.25             6.25
# Total                               8.91             3.54
#
# JobRole        Laboratory Technician  Manager  Manufacturing Director  \
# Education
# Below College                  20.59     5.29                    8.82
# College                        20.21     6.74                   11.70
# Bachelor                       18.18     6.99                    9.44
# Master                         14.57     7.29                    9.55
# PhD                            10.42    10.42                   10.42
# Total                          17.62     6.94                    9.86
#
# JobRole        Research Director  Research Scientist  Sales Executive  \
# Education
# Below College               4.12               21.76            15.88
# College                     4.61               16.31            23.40
# Bachelor                    5.24               21.33            20.98
# Master                      5.78               19.85            25.38
# PhD                        14.58               16.67            25.00
# Total                       5.44               19.86            22.18
#
# JobRole        Sales Representative
# Education
# Below College                 11.76
# College                        5.32
# Bachelor                       5.59
# Master                         4.02
# PhD                            0.00
# Total                          5.65

# %%
pd.crosstab(
    [df_sem_nulo['JobRole'],
    df_sem_nulo['Education']],
    df_sem_nulo['JobLevel'],
    margins=True,
    margins_name="Total",
    
        ).rename(index=mapeamento_educacao)
# Out:
# JobLevel                                   1    2    3    4   5  Total
# JobRole                   Education
# Healthcare Representative Below College    0    8    5    2   0     15
#                           College          0   15    4    2   0     21
#                           Bachelor         0   25   20    3   0     48
#                           Master           0   28   15    1   0     44
#                           PhD              0    2    0    1   0      3
# Human Resources           Below College    4    1    0    0   0      5
#                           College          9    2    1    0   0     12
#                           Bachelor        13    6    3    0   0     22
#                           Master           6    2    2    0   0     10
#                           PhD              1    2    0    0   0      3
# Laboratory Technician     Below College   32    3    0    0   0     35
#                           College         39   16    2    0   0     57
#                           Bachelor        82   21    1    0   0    104
#                           Master          45   13    0    0   0     58
#                           PhD              2    3    0    0   0      5
# Manager                   Below College    0    0    2    4   3      9
#                           College          0    0    1    9   9     19
#                           Bachelor         0    0    6   17  17     40
#                           Master           0    0    3   13  13     29
#                           PhD              0    0    0    4   1      5
# Manufacturing Director    Below College    0   10    4    1   0     15
#                           College          0   24    7    2   0     33
#                           Bachelor         0   26   24    4   0     54
#                           Master           0   28    7    3   0     38
#                           PhD              0    2    3    0   0      5
# Research Director         Below College    0    0    4    0   3      7
#                           College          0    0    5    4   4     13
#                           Bachelor         0    0    8   11  11     30
#                           Master           0    0    9    7   7     23
#                           PhD              0    0    2    4   1      7
# Research Scientist        Below College   35    2    0    0   0     37
#                           College         33   13    0    0   0     46
#                           Bachelor       105   16    1    0   0    122
#                           Master          56   23    0    0   0     79
#                           PhD              5    3    0    0   0      8
# Sales Executive           Below College    0   21    5    1   0     27
#                           College          0   53   13    0   0     66
#                           Bachelor         0   76   35    9   0    120
#                           Master           0   75   22    4   0    101
#                           PhD              0    8    4    0   0     12
# Sales Representative      Below College   18    2    0    0   0     20
#                           College         13    2    0    0   0     15
#                           Bachelor        31    1    0    0   0     32
#                           Master          14    2    0    0   0     16
# Total                                    543  534  218  106  69   1470

# %%
pd.crosstab(
    [df_sem_nulo['JobRole'],df_sem_nulo['JobLevel'],df_sem_nulo['Attrition']],
    df_sem_nulo['Education'],
    margins=True,
    margins_name='Total',
).rename(columns=mapeamento_educacao)
# Out:
# Education                                     Below College  College  \
# JobRole                   JobLevel Attrition
# Healthcare Representative 2        No                     7       13
#                                    Yes                    1        2
#                           3        No                     4        3
#                                    Yes                    1        1
#                           4        No                     2        2
#                                    Yes                    0        0
# Human Resources           1        No                     3        7
#                                    Yes                    1        2
#                           2        No                     1        2
#                           3        No                     0        0
#                                    Yes                    0        1
# Laboratory Technician     1        No                    24       30
#                                    Yes                    8        9
#                           2        No                     3       14
#                                    Yes                    0        2
#                           3        No                     0        1
#                                    Yes                    0        1
# Manager                   3        No                     1        1
#                                    Yes                    1        0
#                           4        No                     4        9
#                           5        No                     2        9
#                                    Yes                    1        0
# Manufacturing Director    2        No                     9       23
#                                    Yes                    1        1
#                           3        No                     4        7
#                                    Yes                    0        0
#                           4        No                     1        2
# Research Director         3        No                     4        5
#                           4        No                     0        4
#                           5        No                     3        4
#                                    Yes                    0        0
# Research Scientist        1        No                    28       26
#                                    Yes                    7        7
#                           2        No                     2       13
#                                    Yes                    0        0
#                           3        No                     0        0
# Sales Executive           2        No                    20       43
#                                    Yes                    1       10
#                           3        No                     3       12
#                                    Yes                    2        1
#                           4        No                     1        0
#                                    Yes                    0        0
# Sales Representative      1        No                    11        6
#                                    Yes                    7        7
#                           2        No                     2        2
#                                    Yes                    0        0
# Total                                                   170      282
#
# Education                                     Bachelor  Master  PhD  Total
# JobRole                   JobLevel Attrition
# Healthcare Representative 2        No               25      28    2     75
#                                    Yes               0       0    0      3
#                           3        No               18      14    0     39
#                                    Yes               2       1    0      5
#                           4        No                2       1    1      8
#                                    Yes               1       0    0      1
# Human Resources           1        No               10       3    0     23
#                                    Yes               3       3    1     10
#                           2        No                6       2    2     13
#                           3        No                2       2    0      4
#                                    Yes               1       0    0      2
# Laboratory Technician     1        No               53      35    2    144
#                                    Yes              29      10    0     56
#                           2        No               19      12    3     51
#                                    Yes               2       1    0      5
#                           3        No                1       0    0      2
#                                    Yes               0       0    0      1
# Manager                   3        No                6       2    0     10
#                                    Yes               0       1    0      2
#                           4        No               17      13    4     47
#                           5        No               15      13    1     40
#                                    Yes               2       0    0      3
# Manufacturing Director    2        No               25      26    2     85
#                                    Yes               1       2    0      5
#                           3        No               23       5    1     40
#                                    Yes               1       2    2      5
#                           4        No                4       3    0     10
# Research Director         3        No                8       9    2     28
#                           4        No               11       7    4     26
#                           5        No               10       6    1     24
#                                    Yes               1       1    0      2
# Research Scientist        1        No               87      44    4    189
#                                    Yes              18      12    1     45
#                           2        No               16      21    3     55
#                                    Yes               0       2    0      2
#                           3        No                1       0    0      1
# Sales Executive           2        No               66      61    7    197
#                                    Yes              10      14    1     36
#                           3        No               26      17    4     62
#                                    Yes               9       5    0     17
#                           4        No                6       3    0     10
#                                    Yes               3       1    0      4
# Sales Representative      1        No               16      11    0     44
#                                    Yes              15       3    0     32
#                           2        No                0       2    0      6
#                                    Yes               1       0    0      1
# Total                                              572     398   48   1470

# %% [markdown]
# # Estatísticas com Pandas
#      Gráficos
#     .Histogramas

# %%
df_sem_nulo.groupby('Gender').size()
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\813534425.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo.groupby('Gender').size()
# Gender
# Female    588
# Male      882
# dtype: int64

# %%
df_sem_nulo.groupby('Gender')['Age'].value_counts(bins=10)
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\1894248262.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo.groupby('Gender')['Age'].value_counts(bins=10)
# Gender  Age
# Female  (34.8, 39.0]                  117
#         (30.6, 34.8]                  108
#         (26.4, 30.6]                   89
#         (39.0, 43.2]                   69
#         (43.2, 47.4]                   56
#         (51.6, 55.8]                   36
#         (47.4, 51.6]                   35
#         (22.2, 26.4]                   32
#         (17.956999999999997, 22.2]     25
#         (55.8, 60.0]                   21
# Male    (34.8, 39.0]                  180
#         (30.6, 34.8]                  157
#         (26.4, 30.6]                  135
#         (39.0, 43.2]                  106
#         (43.2, 47.4]                   75
#         (22.2, 26.4]                   73
#         (47.4, 51.6]                   57
#         (51.6, 55.8]                   41
#         (17.956999999999997, 22.2]     32
#         (55.8, 60.0]                   26
# Name: count, dtype: int64

# %%
df_sem_nulo.groupby('Gender')['Age'].value_counts(bins=10).sort_index()
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\245360925.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo.groupby('Gender')['Age'].value_counts(bins=10).sort_index()
# Gender  Age
# Female  (17.956999999999997, 22.2]     25
#         (22.2, 26.4]                   32
#         (26.4, 30.6]                   89
#         (30.6, 34.8]                  108
#         (34.8, 39.0]                  117
#         (39.0, 43.2]                   69
#         (43.2, 47.4]                   56
#         (47.4, 51.6]                   35
#         (51.6, 55.8]                   36
#         (55.8, 60.0]                   21
# Male    (17.956999999999997, 22.2]     32
#         (22.2, 26.4]                   73
#         (26.4, 30.6]                  135
#         (30.6, 34.8]                  157
#         (34.8, 39.0]                  180
#         (39.0, 43.2]                  106
#         (43.2, 47.4]                   75
#         (47.4, 51.6]                   57
#         (51.6, 55.8]                   41
#         (55.8, 60.0]                   26
# Name: count, dtype: int64

# %%
df_sem_nulo.groupby('Gender')['Age'].value_counts(bins=10,normalize=True).mul(100).round(1).sort_index()
#normalize numeros relativos ou seja porcentagem
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\1028809045.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo.groupby('Gender')['Age'].value_counts(bins=10,normalize=True).mul(100).round(1).sort_index()
# Gender  Age
# Female  (17.956999999999997, 22.2]     4.3
#         (22.2, 26.4]                   5.4
#         (26.4, 30.6]                  15.1
#         (30.6, 34.8]                  18.4
#         (34.8, 39.0]                  19.9
#         (39.0, 43.2]                  11.7
#         (43.2, 47.4]                   9.5
#         (47.4, 51.6]                   6.0
#         (51.6, 55.8]                   6.1
#         (55.8, 60.0]                   3.6
# Male    (17.956999999999997, 22.2]     3.6
#         (22.2, 26.4]                   8.3
#         (26.4, 30.6]                  15.3
#         (30.6, 34.8]                  17.8
#         (34.8, 39.0]                  20.4
#         (39.0, 43.2]                  12.0
#         (43.2, 47.4]                   8.5
#         (47.4, 51.6]                   6.5
#         (51.6, 55.8]                   4.6
#         (55.8, 60.0]                   2.9
# Name: proportion, dtype: float64

# %%
df_sem_nulo.groupby('Gender')['Age'].plot(kind='hist',legend=True,alpha=0.5);
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\1795429033.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo.groupby('Gender')['Age'].plot(kind='hist',legend=True,alpha=0.5);

# %%
df_sem_nulo.hist(column='Age',by='Gender');
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\425262232.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo.hist(column='Age',by='Gender');

# %%
df_sem_nulo.hist(column='Age',by='Gender', sharey=True);
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\4113278818.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo.hist(column='Age',by='Gender', sharey=True);

# %%
df_sem_nulo.hist(column='Age',by='Gender', layout=(2,1), sharex=True , figsize=(5,7));
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\3965579171.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo.hist(column='Age',by='Gender', layout=(2,1), sharex=True , figsize=(5,7));

# %%
df_sem_nulo.groupby('Attrition')['Age'].value_counts(bins=10).sort_index()
# Out:
# Attrition  Age
# No         (17.956999999999997, 22.2]     30
#            (22.2, 26.4]                   76
#            (26.4, 30.6]                  180
#            (30.6, 34.8]                  215
#            (34.8, 39.0]                  267
#            (39.0, 43.2]                  160
#            (43.2, 47.4]                  116
#            (47.4, 51.6]                   81
#            (51.6, 55.8]                   69
#            (55.8, 60.0]                   39
# Yes        (17.959, 22.0]                 27
#            (22.0, 26.0]                   29
#            (26.0, 30.0]                   44
#            (30.0, 34.0]                   50
#            (34.0, 38.0]                   24
#            (38.0, 42.0]                   19
#            (42.0, 46.0]                   14
#            (46.0, 50.0]                   12
#            (50.0, 54.0]                    7
#            (54.0, 58.0]                   11
# Name: count, dtype: int64

# %%
df_sem_nulo.hist(column='Age',by='Attrition', bins=(10));

# %% [markdown]
# ### Função CUT

# %%
faixa_idade = [0, 20, 30, 50, float('inf')] #(0-20] (20-30] (30-50] (50 +]
rotulo = ['Adolecentes', 'Jovem Adulto', 'Adulto Médio', 'Adulto Sênior']

df_sem_nulo['FaixaEtaria'] = pd.cut(df_sem_nulo['Age'], bins=faixa_idade, labels=rotulo)
df_sem_nulo[["Age",'FaixaEtaria']].head(20)
# Out:
#     Age    FaixaEtaria
# 0    41   Adulto Médio
# 1    49   Adulto Médio
# 2    37   Adulto Médio
# 3    33   Adulto Médio
# 4    27   Jovem Adulto
# 5    32   Adulto Médio
# 6    59  Adulto Sênior
# 7    30   Jovem Adulto
# 8    38   Adulto Médio
# 9    36   Adulto Médio
# 10   35   Adulto Médio
# 11   29   Jovem Adulto
# 12   31   Adulto Médio
# 13   34   Adulto Médio
# 14   28   Jovem Adulto
# 15   29   Jovem Adulto
# 16   32   Adulto Médio
# 17   22   Jovem Adulto
# 18   53  Adulto Sênior
# 19   38   Adulto Médio

# %%
df_sem_nulo["FaixaEtaria"].value_counts()
# Out:
# FaixaEtaria
# Adulto Médio     941
# Jovem Adulto     358
# Adulto Sênior    143
# Adolecentes       28
# Name: count, dtype: int64

# %%
df_sem_nulo["FaixaEtaria"].value_counts().sort_index()
# Out:
# FaixaEtaria
# Adolecentes       28
# Jovem Adulto     358
# Adulto Médio     941
# Adulto Sênior    143
# Name: count, dtype: int64

# %%
df_sem_nulo["FaixaEtaria"].value_counts().sort_index().plot(kind='bar');

# %%
pd.crosstab(df_sem_nulo["FaixaEtaria"], df_sem_nulo['Attrition'], normalize='index').mul(100).round(1).style.background_gradient(cmap="RdYlGn",axis='columns')
# Out:
# <style type="text/css">
# #T_4ca6a_row0_col0, #T_4ca6a_row1_col1, #T_4ca6a_row2_col1, #T_4ca6a_row3_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4ca6a_row0_col1, #T_4ca6a_row1_col0, #T_4ca6a_row2_col0, #T_4ca6a_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4ca6a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_4ca6a_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_4ca6a_level0_col1" class="col_heading level0 col1" >Yes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >FaixaEtaria</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ca6a_level0_row0" class="row_heading level0 row0" >Adolecentes</th>
#       <td id="T_4ca6a_row0_col0" class="data row0 col0" >42.900000</td>
#       <td id="T_4ca6a_row0_col1" class="data row0 col1" >57.100000</td>
#     </tr>
#     <tr>
#       <th id="T_4ca6a_level0_row1" class="row_heading level0 row1" >Jovem Adulto</th>
#       <td id="T_4ca6a_row1_col0" class="data row1 col0" >76.500000</td>
#       <td id="T_4ca6a_row1_col1" class="data row1 col1" >23.500000</td>
#     </tr>
#     <tr>
#       <th id="T_4ca6a_level0_row2" class="row_heading level0 row2" >Adulto Médio</th>
#       <td id="T_4ca6a_row2_col0" class="data row2 col0" >87.400000</td>
#       <td id="T_4ca6a_row2_col1" class="data row2 col1" >12.600000</td>
#     </tr>
#     <tr>
#       <th id="T_4ca6a_level0_row3" class="row_heading level0 row3" >Adulto Sênior</th>
#       <td id="T_4ca6a_row3_col0" class="data row3 col0" >87.400000</td>
#       <td id="T_4ca6a_row3_col1" class="data row3 col1" >12.600000</td>
#     </tr>
#   </tbody>
# </table>

# %%
colunas_categoricas_ordenadas.append('FaixaEtaria')

# %%
df_sem_nulo[colunas_numericas].hist(figsize=(15,10));

# %% [markdown]
# ### Boxplots

# %%
df_sem_nulo['DistanceFromHome'].hist()
# Out:
# <Axes: >

# %%
df_sem_nulo.boxplot(column='DistanceFromHome', vert=False, grid=False)
# Out:
# <Axes: >

# %%
df_sem_nulo.groupby(['Gender','Attrition'])['Age'].describe()
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\1237392480.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo.groupby(['Gender','Attrition'])['Age'].describe()
#                   count       mean       std   min   25%   50%    75%   max
# Gender Attrition
# Female No         501.0  38.155689  9.001762  18.0  31.0  37.0  45.00  60.0
#        Yes         87.0  32.574713  9.385333  18.0  27.0  31.0  36.50  58.0
# Male   No         732.0  37.154372  8.792917  18.0  31.0  36.0  43.00  60.0
#        Yes        150.0  34.206667  9.842584  18.0  28.0  32.0  39.75  58.0

# %%
df_sem_nulo.boxplot(column='Age',by=['Gender','Attrition'], grid=False,showmeans=True);

# %%
df_sem_nulo.groupby('JobLevel')['Age'].describe()
# Out:
#           count       mean       std   min   25%   50%   75%   max
# JobLevel
# 1         543.0  32.524862  8.463882  18.0  27.0  31.0  37.0  59.0
# 2         534.0  36.599251  7.503875  22.0  31.0  35.5  41.0  60.0
# 3         218.0  40.087156  8.114771  27.0  34.0  38.0  46.0  60.0
# 4         106.0  47.537736  6.485404  29.0  43.0  48.0  53.0  59.0
# 5          69.0  47.753623  5.778779  39.0  42.0  48.0  52.0  60.0

# %%
df_sem_nulo.boxplot(column='Age',by=['JobLevel'], grid=False,showmeans=True);

# %%
df_sem_nulo.groupby(['JobRole','Gender','JobLevel'])['MonthlyIncome'].describe()
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\2546982848.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo.groupby(['JobRole','Gender','JobLevel'])['MonthlyIncome'].describe()
#                                            count          mean          std  \
# JobRole                   Gender JobLevel
# Healthcare Representative Female 2          31.0   5882.838710  1601.010475
#                                  3          17.0   9123.058824  1305.181188
#                                  4           3.0  13888.000000   133.371661
#                           Male   2          47.0   5853.808511  1026.214204
#                                  3          27.0   9515.629630  1312.786735
#                                  4           6.0  12515.500000  1165.564885
# Human Resources           Female 1          10.0   2653.000000   473.966244
#                                  2           3.0   5859.333333   602.412096
#                                  3           3.0   9514.333333   594.553894
#                           Male   1          23.0   2768.086957   796.490365
#                                  2          10.0   5474.700000  1015.903982
#                                  3           3.0   9731.666667  1514.939713
# Laboratory Technician     Female 1          67.0   2821.208955   665.705607
#                                  2          17.0   4680.176471  1135.106341
#                                  3           1.0   7403.000000          NaN
#                           Male   1         133.0   2871.406015   814.399063
#                                  2          39.0   4357.743590  1301.237058
#                                  3           2.0   5295.500000   120.915260
# Manager                   Female 3           7.0  12376.000000   730.209787
#                                  4          23.0  16657.086957   790.448027
#                                  5          17.0  19133.705882   582.842363
#                           Male   3           5.0  12032.800000   920.125372
#                                  4          24.0  16571.291667  1103.257803
#                                  5          26.0  19216.846154   513.599587
# Manufacturing Director    Female 2          41.0   5259.731707   821.601181
#                                  3          23.0   9189.391304  1351.339058
#                                  4           8.0  13306.875000   375.310324
#                           Male   2          49.0   5908.142857  1551.159969
#                                  3          22.0   9430.045455  1198.465506
#                                  4           2.0  13687.500000   403.757972
# Research Director         Female 3          16.0  12652.000000   988.025708
#                                  4          10.0  16349.100000   853.426225
#                                  5           7.0  19120.714286   645.621332
#                           Male   3          12.0  12814.333333   824.694140
#                                  4          16.0  16479.000000  1271.443956
#                                  5          19.0  19235.789474   420.039625
# Research Scientist        Female 1          87.0   2869.873563   800.612611
#                                  2          27.0   4873.740741  1200.243039
#                           Male   1         147.0   2802.659864   730.420638
#                                  2          30.0   4769.566667   889.066177
#                                  3           1.0   9724.000000          NaN
# Sales Executive           Female 2          98.0   5669.142857  1254.471861
#                                  3          27.0   9075.407407  1184.644161
#                                  4           7.0  13182.428571   549.261582
#                           Male   2         135.0   5896.518519  1533.774112
#                                  3          52.0   9150.730769  1253.430948
#                                  4           7.0  13222.571429   702.481283
# Sales Representative      Female 1          35.0   2516.771429   539.688804
#                                  2           3.0   4482.333333   932.655528
#                           Male   1          41.0   2498.146341   711.439898
#                                  2           4.0   3500.000000  2122.029846
#
#                                                min       25%      50%  \
# JobRole                   Gender JobLevel
# Healthcare Representative Female 2          4014.0   4522.50   5731.0
#                                  3          7094.0   7978.00   8823.0
#                                  4         13734.0  13849.00  13964.0
#                           Male   2          4000.0   5265.50   5745.0
#                                  3          7005.0   8566.50   9884.0
#                                  4         11103.0  11476.00  12832.5
# Human Resources           Female 1          2109.0   2181.75   2741.5
#                                  2          5204.0   5594.50   5985.0
#                                  3          8837.0   9296.50   9756.0
#                           Male   1          1555.0   2222.00   2592.0
#                                  2          3886.0   4622.75   5910.0
#                                  3          7988.0   9235.00  10482.0
# Laboratory Technician     Female 1          1129.0   2388.50   2743.0
#                                  2          2406.0   4011.00   4627.0
#                                  3          7403.0   7403.00   7403.0
#                           Male   1          1102.0   2293.00   2660.0
#                                  2          2042.0   3449.00   4404.0
#                                  3          5210.0   5252.75   5295.5
# Manager                   Female 3         11631.0  11897.00  11996.0
#                                  4         14756.0  16185.50  16752.0
#                                  5         18041.0  18824.00  19094.0
#                           Male   3         11244.0  11557.00  11849.0
#                                  4         14026.0  16222.00  16870.5
#                                  5         18200.0  19050.75  19217.0
# Manufacturing Director    Female 2          4011.0   4663.00   5121.0
#                                  3          7143.0   7808.50   9667.0
#                                  4         12742.0  13097.75  13242.0
#                           Male   2          4033.0   4775.00   5762.0
#                                  3          7260.0   8500.00   9480.0
#                                  4         13402.0  13544.75  13687.5
# Research Director         Female 3         11031.0  11896.00  13198.5
#                                  4         14275.0  16139.00  16417.5
#                                  5         18172.0  18702.50  19049.0
#                           Male   3         11510.0  12122.50  13026.5
#                                  4         14336.0  15543.75  16817.0
#                                  5         18265.0  19112.50  19328.0
# Research Scientist        Female 1          1261.0   2295.00   2632.0
#                                  2          2133.0   4435.50   4869.0
#                           Male   1          1009.0   2341.00   2703.0
#                                  2          3055.0   4257.75   4817.5
#                                  3          9724.0   9724.00   9724.0
# Sales Executive           Female 2          4028.0   4669.25   5461.0
#                                  3          7314.0   7786.00   9071.0
#                                  4         12031.0  13203.00  13225.0
#                           Male   2          4001.0   4726.00   5441.0
#                                  3          7082.0   8125.75   9245.5
#                                  4         11836.0  13028.00  13341.0
# Sales Representative      Female 1          1200.0   2225.50   2572.0
#                                  2          3540.0   4021.00   4502.0
#                           Male   1          1052.0   2269.00   2476.0
#                                  2          2086.0   2251.00   2641.0
#
#                                                 75%      max
# JobRole                   Gender JobLevel
# Healthcare Representative Female 2          6749.00   9824.0
#                                  3         10312.00  10938.0
#                                  4         13965.00  13966.0
#                           Male   2          6563.00   8853.0
#                                  3         10584.50  10999.0
#                                  4         13501.25  13577.0
# Human Resources           Female 1          2922.25   3423.0
#                                  2          6187.00   6389.0
#                                  3          9853.00   9950.0
#                           Male   1          2973.50   4936.0
#                                  2          6328.25   6430.0
#                                  3         10603.50  10725.0
# Laboratory Technician     Female 1          3253.00   4364.0
#                                  2          5363.00   6674.0
#                                  3          7403.00   7403.0
#                           Male   1          3500.00   4876.0
#                                  2          5380.50   6782.0
#                                  3          5338.25   5381.0
# Manager                   Female 3         12810.00  13591.0
#                                  4         17148.50  17875.0
#                                  5         19566.00  19943.0
#                           Male   3         11904.00  13610.0
#                                  4         17246.75  17924.0
#                                  5         19606.25  19999.0
# Manufacturing Director    Female 2          5980.00   6877.0
#                                  3         10384.00  10880.0
#                                  4         13609.00  13826.0
#                           Male   2          6434.00   9957.0
#                                  3         10452.50  10976.0
#                                  4         13830.25  13973.0
# Research Director         Female 3         13511.50  13744.0
#                                  4         16836.00  17328.0
#                                  5         19623.00  19973.0
#                           Male   3         13514.00  13757.0
#                                  4         17588.75  17861.0
#                                  5         19519.50  19740.0
# Research Scientist        Female 1          3361.00   4968.0
#                                  2          5536.00   6962.0
#                           Male   1          3109.50   4930.0
#                                  2          5452.75   6646.0
#                                  3          9724.00   9724.0
# Sales Executive           Female 2          6321.25   9981.0
#                                  3         10248.50  10934.0
#                                  4         13422.50  13770.0
#                           Male   2          6580.00   9998.0
#                                  3         10335.75  10932.0
#                                  4         13726.50  13872.0
# Sales Representative      Female 1          2813.50   3931.0
#                                  2          4953.50   5405.0
#                           Male   1          2858.00   4400.0
#                                  2          3890.00   6632.0

# %%
job_roles = df_ibm['JobRole'].unique()

job_roles
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
for job in job_roles:
    df_sem_nulo[df_sem_nulo['JobRole'] == job].boxplot(column='MonthlyIncome', by= ['Gender','JobLevel'],grid=False, showmeans=True)

# %%
for job in job_roles:
    df_sem_nulo[df_sem_nulo['JobRole'] == job].plot(kind='box',column='MonthlyIncome', by= ['Gender','JobLevel'],grid=False, showmeans=True);
# Out:
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\216830543.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo[df_sem_nulo['JobRole'] == job].plot(kind='box',column='MonthlyIncome', by= ['Gender','JobLevel'],grid=False, showmeans=True);
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\216830543.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo[df_sem_nulo['JobRole'] == job].plot(kind='box',column='MonthlyIncome', by= ['Gender','JobLevel'],grid=False, showmeans=True);
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\216830543.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo[df_sem_nulo['JobRole'] == job].plot(kind='box',column='MonthlyIncome', by= ['Gender','JobLevel'],grid=False, showmeans=True);
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\216830543.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo[df_sem_nulo['JobRole'] == job].plot(kind='box',column='MonthlyIncome', by= ['Gender','JobLevel'],grid=False, showmeans=True);
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\216830543.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo[df_sem_nulo['JobRole'] == job].plot(kind='box',column='MonthlyIncome', by= ['Gender','JobLevel'],grid=False, showmeans=True);
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\216830543.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo[df_sem_nulo['JobRole'] == job].plot(kind='box',column='MonthlyIncome', by= ['Gender','JobLevel'],grid=False, showmeans=True);
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\216830543.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo[df_sem_nulo['JobRole'] == job].plot(kind='box',column='MonthlyIncome', by= ['Gender','JobLevel'],grid=False, showmeans=True);
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\216830543.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo[df_sem_nulo['JobRole'] == job].plot(kind='box',column='MonthlyIncome', by= ['Gender','JobLevel'],grid=False, showmeans=True);
# C:\Users\a0090793\AppData\Local\Temp\ipykernel_42116\216830543.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_sem_nulo[df_sem_nulo['JobRole'] == job].plot(kind='box',column='MonthlyIncome', by= ['Gender','JobLevel'],grid=False, showmeans=True);
